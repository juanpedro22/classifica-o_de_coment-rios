# %%
import nltk

#nltk.download()

# %%
basetreinamento = [
 ('gostei muito do atendimento','atendimento.pos'),
 ('atendimento de primeira','atendimento.pos'),
 ('funcionarios educados e simpáticos','atendimento.pos'),
 ('atendimento rapido','atendimento.pos'),
 ('sem filas para ser atendido', 'atendimento.pos'),
 ('atendentes muito educados','atendimento.pos'),
 ('excelente atendimento','atendimento.pos'),
 ('muito rápido','atendimento.pos'),
 ('adorei','atendimento.pos'),
 ('muito bacana a organização e o atendimento','atendimento.pos'),
 ('muito bom o serviço','atendimento.pos'),
 ('atendentes muito gentis e educados','atendimento.pos'),
 ('excelência no atendimento','atendimento.pos'),
 ('o caixa foi muito honesto','atendimento.pos'),
 ('pessoal na limpeza muito eficientes','atendimento.pos'),
 ('gostei muito do caixa','atendimento.pos'),
 ('pagamento fácil e sem enrolação ou demora','atendimento.pos'),
 ('melhor atendimento que já tive em uma barbearia','atendimento.pos'),
 ('barbeiro muito rápido e atencioso','atendimento.pos'),
 ('estão de parabens, todos muito atenciosos no atendimento','atendimento.pos'),
 ('parabens pelo atendimento','atendimento.pos'),
 ('me surpreendi com a rapidez','atendimento.pos'),
 ('achei ótimo o atendimento','atendimento.pos'),
 ('ótimo atendimento','atendimento.pos'),
 ('me surpreendeu a eficiencia da equipe','atendimento.pos'),
 ('toda a equipe está de parabens','atendimento.pos'),
 ('a barbearia respeita o cliente e oferece bons serviços','atendimento.pos'),
 ('foi uma experiência muito boa','atendimento.pos'),
 ('gostaria de agradecer pelo ótimo serviço','atendimento.pos'),
 ('continuem o bom trabalho','atendimento.pos'),
 ('mandaram bem no atendimento','atendimento.pos'),
 ('barbeiro muito educado e talentoso','atendimento.pos'),
 ('todos muito prestativos e educados','atendimento.pos'),
 ('gostei muito da gentileza dos seguranças','atendimento.pos'),
 ('equipe muito organizada','atendimento.pos'),
 ('o barbeiro é incrível','atendimento.pos'),
 ('a barbearia é excelente','atendimento.pos'),
 ('o barbeiro é muito bom e trabalha muito bem','atendimento.pos'),
 ('muito simpático o barbeiro e atencioso','atendimento.pos'),
 ('sensacional o barbeiro','atendimento.pos'),
 ('barbeiros muito competentes, estão de parabéns','atendimento.pos'),
 ('a secretária é muito prestativa e educada','atendimento.pos'),
 ('melhor barbeiro da cidade','atendimento.pos'),
 ('muito bacana o sistema de atendimento','atendimento.pos'),
 ('o serviço é excelente','atendimento.pos'),
 ('toda a equipe é muito organizada','atendimento.pos'),
 ('respeita o horario marcado','atendimento.pos'),
 ('fiquei surpreso com a qualidade dos serviço','atendimento.pos'),
 ('a padaria é pontual com as entregas','atendimento.pos'),
 ('o barbeiro é muito bom e rápido','atendimento.pos'),
 ('o barbeiro sabe o que faz','atendimento.pos'),
 ('obrigado pelo atendimento de primeira','atendimento.pos'),
 ('continuem com o excelente atendimento','atendimento.pos'),
 ('não troco a barbearia por nenhuma outra','atendimento.pos'),
 ('melhor Barbearia','atendimento.pos'),
 ('vocês são fantásticos','atendimento.pos'),
 ('exemplo de Babearia','atendimento.pos'),
 ('são bons de serviço','atendimento.pos'),
('muito escuro e pouco ventilado','ambiente.neg'),
('muito quente o ambiente','ambiente.neg'),
('faltam ventiladores ou ar condicionado','ambiente.neg'),
('espelho quebrado','ambiente.neg'),
('a luz do banheiro estava queimada','ambiente.neg'),
('banheiro sujo e fedido','ambiente.neg'),
('pouca higiene no local em que oa pães ficam','ambiente.neg'),
('pouca higiene no local de armazenar os pães','ambiente.neg'),
('muitos mosquitos e insetos no local','ambiente.neg'),
('encontrei uma baratinha no chão','ambiente.neg'),
('encontrei um barata no balcão','ambiente.neg'),
('muita fila para pagar','ambiente.neg'),
('decoração não combina','ambiente.neg'),
('não gostei deste lugar','ambiente.neg'),
('muito fraco, não gostei da organização nem do ambiente','ambiente.neg'),
('não tem banheiro para clientes no local','ambiente.neg'),
('desconfortavel esperar para ser atendido','ambiente.neg'),
('muito cheio, e demora para ser atendido','ambiente.neg'),
('sem rampa de acesso para deficientes','ambiente.neg'),
('pouca acessibilidade para cadeirantes','ambiente.neg'),
('não tem rampas de acesso','ambiente.neg'),
('o ambiente não está preparado para atender cadeirantes e deficientes físicos','ambiente.neg'),
('falta um ar condicionado','ambiente.neg'),
('sem estacionamento','ambiente.neg'),
('não tem estacionamento','ambiente.neg'),
('muito dificil parar o carro para ir na padaria','ambiente.neg'),
('muito apertado a passagem para o caixa','ambiente.neg'),
('balcões antigos e sem iluminação','ambiente.neg'),
('quadros ridículos nas paredes','ambiente.neg'),
('muito dificil a catraca','ambiente.neg'),
('muito ruim o sistema de catraca','ambiente.neg'),
('não estava funcionando a catraca','ambiente.neg'),
('ambiente feio e faltou criatividade na decoração','ambiente.neg'),
('sem criatividade para decorar','ambiente.neg'),
('não entendi a lógica das plateleiras','ambiente.neg'),
('funcionários não tem uniforme','ambiente.neg'),
('ninguém tem uniforme','ambiente.neg'),
('muito pequeno e bagunçado','ambiente.neg'),
('não parece um ambiente limpo','ambiente.neg'),
('tudo antigo e com cara de não funcionar','ambiente.neg'),
('lugar estranho','ambiente.neg'),
('não tem toldo','ambiente.neg'),
('tinha goteira dentro da barbearia','ambiente.neg'),
('não tinha cadeiras o suficiente','ambiente.neg'), 
('músicas ruins','ambiente.neg'), 
('playlist ruim e fraca','ambiente.neg'), 
('músicas não combinam com o ambiente','ambiente.neg'),  
('não tem cadeira para os idosos esperarem os pedidos','ambiente.neg'),   
('não tem cadeiras para aguardar os pedidos','ambiente.neg'),    

    
('não gostei do corte','produto.neg'),
('não gostei de como ficou o corte, estava duro e velho','produto.neg'),
('não gostei do pezinho','produto.neg'),
('muito ruim o corte de cabelo','produto.neg'),
('ficou estranho o resultado final','produto.neg'),
('cortou muito o cabelo','produto.neg'),
('cortou mais do que eu queria','produto.neg'),
('não gostei','produto.neg'),
('ficou feioo','produto.neg'),
('muito curto','produto.neg'),
('ficou com falhas','produto.neg'),
('muitas falhas','produto.neg'),
('navalha velha','produto.neg'),
('não usa navalha descartavel','produto.neg'),
('horrível o corte','produto.neg'),
('horrível o o penteado','produto.neg'),
('a maquininha machuca','produto.neg'),
('muito caro e ruim','produto.neg'),
('falta limpeza no banheiro, estava muito sujo','ambiente.neg'),
('pessíma iluminação em todo o ambiente','ambiente.neg'),
('sistema de pagamentos não funciona direito','ambiente.neg'),
('muito fedida a padaria','ambiente.neg'),
('não gostei da pintura nas paredes','ambiente.neg'),
('muita pichação nas paredes externas da barbearia','ambiente.neg'),
('o ambiente é muito escuro e mal iluminado','ambiente.neg'),
('faltam cadeira e mesas no estabelecimento','ambiente.neg'),
('mesas sujas e cadeiras quebradas','ambiente.neg'),
('falta um ar condicionado, muito quente o ambiente','ambiente.neg'),
('muito quente o lugar e pouco ventilado','ambiente.neg'),
('plateleiras vazias','ambiente.neg'),
('falta organização','ambiente.neg'),
('muito desorganizado e mal iluminado','ambiente.neg'),
('não gostei do interior do ambiente','ambiente.neg'),
('não gostei da entrada','ambiente.neg'),
('muito feio o inteior precisa modernizar','ambiente.neg'),     

('o corte de cabelo é muito caro','produto.neg'),
('não gostei do acabamento','produto.neg'),
('o cabelo fica todo torto, muito ruim','produto.neg'),
('muito ruim o o corte de cabelo','produto.neg'),
('ficou feio o cabelo, não gostei','produto.neg'),
('corte de cabelo não combina','produto.neg'),
('o corte de cabelo estava horrível','produto.neg'),
('muito mal feito','produto.neg'),
('poderia ter sido melhor esse corte','produto.neg'),
('paguei caro pelo corte','produto.neg'),
('uma porcaria o trabalho de vocês','produto.neg'),
('não gostei nem um pouco do corte de cabelo','produto.neg'),
('achei a qualidade dos produtos questionaveis','produto.neg'),
('o bigode ficou torto e mal feito','produto.neg'),
('me cortou o rosto todo com a lamina','produto.neg'),
('horrível os produtos','produto.neg'),
('tinham muitos produtos vencidos nas plateleiras','produto.neg'),
('muito caro os cortes','produto.neg'),
('não tem variedades de produtos','produto.neg'),
('paguei caro de mais por um corte ruim','produto.neg'),
('não ficou boa minha aparência depois do corte','produto.neg'),
('fiquei ridiculo com o corte que me fizeram','produto.neg'),
('um lixo o corte de cabelo feito pelo barbeiro','produto.neg'),
('horrível o degrade, tudo errado','produto.neg'),
('poderia ser menos caro os produtos','produto.neg'),
('produtos não funcionam','produto.neg'),
('faltam produtos nas plateleiras','produto.neg'),
('corte horrivel','produto.neg'),
('horroroso o corte que fizeram','produto.neg'),
('porcaria que fizeram na minha cabeça','produto.neg'),
('não gostei nem um pouco dos produtos','produto.neg'),
('infelizmente os produtos são ruins','produto.neg'),
('fiquei insatisfeito com o corte','produto.neg'),
('não compativel com preço','produto.neg'),
('alto valor para produtos ruins','produto.neg'),
('o shampoo estava horrível','produto.neg'),

('muito bom o atendimento','atendimento.pos'),    
('adorei o atendimento de vocês','atendimento.pos'),
('a equipe é sensacional, muito bons em tudo','atendimento.pos'),
('são muito eficientes','atendimento.pos'),
('muito bom todos os serviços oferecidos','atendimento.pos'),
('obrigado ao pessoal da limpeza, foram muito gentis em me ajudar','atendimento.pos'),
('muito rápido o processo','atendimento.pos'), 
('foi bom de mais todo o atendimento','atendimento.pos'),
('excelente serviço, muito rápido e profissional','atendimento.pos'),
('equipe maravilhosa','atendimento.pos'),
('muito eficiente o sistema de pagamentos','atendimento.pos'),
('muito confusa a organização e sem ninguém paa ajudar','atendimento.neg'),
('muito ruim o atendimento da barbearia','atendimento.neg'),
('não prestam um bom serviço','atendimento.neg'),
('não gostei do atendimento, muitas falhas e aborrecimentos com os funcionários','atendimento.neg'),    

]

# %%
stopwords = ['a', 'agora', 'algum', 'alguma', 'aquele', 'aqueles', 'de', 'deu', 'do', 'e', 'estou', 'esta', 'esta',
             'ir', 'meu', 'muito', 'mesmo', 'no', 'nossa', 'o', 'outro', 'para', 'que', 'sem', 'talvez', 'tem', 'tendo',
             'tenha', 'teve', 'tive', 'todo', 'um', 'uma', 'umas', 'uns', 'vou']

stopwordsnltk = nltk.corpus.stopwords.words('portuguese')
stopwordsnltk.append('vou')
stopwordsnltk.append('tão')
print(stopwordsnltk)
# Out:
# ['de', 'a', 'o', 'que', 'e', 'é', 'do', 'da', 'em', 'um', 'para', 'com', 'não', 'uma', 'os', 'no', 'se', 'na', 'por', 'mais', 'as', 'dos', 'como', 'mas', 'ao', 'ele', 'das', 'à', 'seu', 'sua', 'ou', 'quando', 'muito', 'nos', 'já', 'eu', 'também', 'só', 'pelo', 'pela', 'até', 'isso', 'ela', 'entre', 'depois', 'sem', 'mesmo', 'aos', 'seus', 'quem', 'nas', 'me', 'esse', 'eles', 'você', 'essa', 'num', 'nem', 'suas', 'meu', 'às', 'minha', 'numa', 'pelos', 'elas', 'qual', 'nós', 'lhe', 'deles', 'essas', 'esses', 'pelas', 'este', 'dele', 'tu', 'te', 'vocês', 'vos', 'lhes', 'meus', 'minhas', 'teu', 'tua', 'teus', 'tuas', 'nosso', 'nossa', 'nossos', 'nossas', 'dela', 'delas', 'esta', 'estes', 'estas', 'aquele', 'aquela', 'aqueles', 'aquelas', 'isto', 'aquilo', 'estou', 'está', 'estamos', 'estão', 'estive', 'esteve', 'estivemos', 'estiveram', 'estava', 'estávamos', 'estavam', 'estivera', 'estivéramos', 'esteja', 'estejamos', 'estejam', 'estivesse', 'estivéssemos', 'estivessem', 'estiver', 'est
# ...

# %%
def removestopwords(texto):
    frases = []
    for (palavras, emocao) in texto:
        semstop = [p for p in palavras.split() if p not in stopwordsnltk]
        frases.append((semstop, emocao))
    return frases
print(removestopwords(basetreinamento))
# Out:
# [(['gostei', 'atendimento'], 'atendimento.pos'), (['atendimento', 'primeira'], 'atendimento.pos'), (['funcionarios', 'educados', 'simpáticos'], 'atendimento.pos'), (['atendimento', 'rapido'], 'atendimento.pos'), (['filas', 'ser', 'atendido'], 'atendimento.pos'), (['atendentes', 'educados'], 'atendimento.pos'), (['excelente', 'atendimento'], 'atendimento.pos'), (['rápido'], 'atendimento.pos'), (['adorei'], 'atendimento.pos'), (['bacana', 'organização', 'atendimento'], 'atendimento.pos'), (['bom', 'serviço'], 'atendimento.pos'), (['atendentes', 'gentis', 'educados'], 'atendimento.pos'), (['excelência', 'atendimento'], 'atendimento.pos'), (['caixa', 'honesto'], 'atendimento.pos'), (['pessoal', 'limpeza', 'eficientes'], 'atendimento.pos'), (['gostei', 'caixa'], 'atendimento.pos'), (['pagamento', 'fácil', 'enrolação', 'demora'], 'atendimento.pos'), (['melhor', 'atendimento', 'barbearia'], 'atendimento.pos'), (['barbeiro', 'rápido', 'atencioso'], 'atendimento.pos'), (['parabens,', 'todos',
# ...

# %%
def aplicastemmer(texto):
    stemmer = nltk.stem.RSLPStemmer()
    frasessstemming = []
    for (palavras, emocao) in texto:
        comstemming = [str(stemmer.stem(p)) for p in palavras.split() if p not in stopwordsnltk]
        frasessstemming.append((comstemming, emocao))
    return frasessstemming

frasescomstemmingtreinamento = aplicastemmer(basetreinamento)
frasescomstemmingteste = aplicastemmer(baseteste)
#print(frasescomstemmingteste)

# %%
def buscapalavras(frases):
    todaspalavras = []
    for (palavras, emocao) in frases:
        todaspalavras.extend(palavras)
    return todaspalavras

palavrastreinamento = buscapalavras(frasescomstemmingtreinamento)
palavrasteste = buscapalavras(frasescomstemmingteste)
#print(palavrasteste)

# %%
def buscafrequencia(palavras):
    palavras = nltk.FreqDist(palavras)
    return palavras

frequenciatreinamento = buscafrequencia(palavrastreinamento)
frequenciateste = buscafrequencia(palavrasteste)
print(frequenciateste.most_common(50))
# Out:
# [('cort', 45), ('atend', 24), ('bom', 22), ('gost', 22), ('cabel', 21), ('barbe', 16), ('produt', 16), ('muit', 13), ('tod', 12), ('tud', 12), ('mal', 11), ('fic', 10), ('qual', 10), ('melhor', 10), ('bonit', 10), ('ambi', 9), ('lug', 9), ('falt', 8), ('ruim', 8), ('decor', 7), ('organiz', 7), ('efici', 7), ('ilumin', 7), ('funcion', 7), ('trabalh', 6), ('pad', 6), ('pag', 6), ('pouc', 6), ('serviç', 6), ('dem', 6), ('feit', 5), ('modern', 5), ('val', 5), ('lugar,', 5), ('ach', 5), ('car', 5), ('rápid', 5), ('recom', 4), ('ador', 4), ('preç', 4), ('pen', 4), ('fiz', 4), ('barb', 4), ('alt', 4), ('maravilh', 4), ('ser', 4), ('sistem', 4), ('suj', 4), ('fil', 4), ('caix', 4)]

# %%
def buscapalavrasunicas(frequencia):
    freq = frequencia.keys()
    return freq

palavrasunicastreinamento = buscapalavrasunicas(frequenciatreinamento)
palavrasunicasteste = buscapalavrasunicas(frequenciateste)
#print(palavrasunicastreinamento)

print(palavrasunicasteste)
# Out:
# dict_keys(['bom', 'cort', 'feit', 'barbe', 'show', 'cabel', 'fic', 'mais,', 'recom', 'tod', 'coleg', 'recomend', 'gost', 'trabalh', 'feito,', 'parabém', 'agradec', 'cabelo!', 'qual', 'impression', 'acab', 'venh', 'coment', 'elogi', 'cabelo,', 'profiss', 'excl', 'pe', 'obrig', 'excel', 'modern', 'ador', 'degrad', 'soub', 'encontr', 'perfeit', 'format', 'cabeç', 'preç', 'just', 'val', 'pen', 'experiment', 'tud', 'bem', 'gent', 'fer', 'mand', 'melhor', 'cidad', 'inteira!', 'simples', 'barato,', 'd', 'edepoil', 'fiz', 'barb', 'fant', 'produt', 'incr', 'barbearia,', 'anti-casp', 'lá', 'alt', 'prim', 'serie,', 'joã', 'faz', 'super', 'expect', 'fax', 'estrut', 'lind', 'lugar,', 'conhec', 'maravilh', 'decor', 'infraestrut', 'eleg', 'sofistic', 'pad', 'bonit', 'ambi', 'organiz', 'efici', 'lug', 'ótim', 'ilumin', 'apar', 'limpinho,', 'difer', 'aconcheg', 'pared', 'lindo', 'balc', 'ser', 'agon', 'sistem', 'pag', 'inov', 'entr', 'rest', 'bel', 'nunc', 'vi', 'dá', 'vontad', 'compr', 'dess', 'par'
# ...

# %%
def extratorpalavras(documento):
    doc = set(documento)
    caracteristicas = {}
    for palavras in palavrasunicastreinamento:
        caracteristicas['%s' % palavras] = (palavras in doc)
    return caracteristicas

caracteristicasfrase = extratorpalavras(['am', 'nov', 'dia'])
#print(caracteristicasfrase)

# %%
basecompletatreinamento = nltk.classify.apply_features(extratorpalavras, frasescomstemmingtreinamento)
basecompletateste = nltk.classify.apply_features(extratorpalavras, frasescomstemmingteste)
#print(basecompletateste[15])

# %%
# constroi a tabela de probabilidade
classificador = nltk.NaiveBayesClassifier.train(basecompletatreinamento)
print(classificador.labels())
#print(classificador.show_most_informative_features(20))

print(nltk.classify.accuracy(classificador, basecompletateste))
# Out:
# ['atendimento.pos', 'produto.pos', 'ambiente.pos', 'ambiente.neg', 'produto.neg', 'atendimento.neg']
# 0.7123287671232876

# %%
erros = []
for (frase, classe) in basecompletateste:
    #print(frase)
    #print(classe)
    resultado = classificador.classify(frase)
    if resultado != classe:
        erros.append((classe, resultado, frase))
#for (classe, resultado, frase) in erros:
    #print(classe, resultado, frase)

# %%
from nltk.metrics import ConfusionMatrix
esperado = []
previsto = []
for (frase, classe) in basecompletateste:
    resultado = classificador.classify(frase)
    previsto.append(resultado)
    esperado.append(classe)

# %%
#esperado = 'alegria alegria alegria alegria medo medo surpresa surpresa'.split()
#previsto = 'alegria alegria medo surpresa medo medo medo surpresa'.split()
matriz = ConfusionMatrix(esperado, previsto)
print(matriz)
# Out:
#                  |              p             |
#                  |        a  a  a             |
#                  |        t  t  t             |
#                  |        e  e  e             |
#                  |  a  a  n  n  n           p |
#                  |  m  m  d  d  d     p  p  r |
#                  |  b  b  i  i  i     r  r  o |
#                  |  i  i  m  m  m     o  o  d |
#                  |  e  e  e  e  e  p  d  d  u |
#                  |  n  n  n  n  n  o  u  u  t |
#                  |  t  t  t  t  t  s  t  t  o |
#                  |  e  e  o  o  o  i  o  o  . |
#                  |  .  .  .  .  .  t  .  .  p |
#                  |  n  p  n  p  n  i  n  p  o |
#                  |  e  o  e  o  e  v  e  o  s |
#                  |  g  s  g  s  g  o  g  s  o |
# -----------------+----------------------------+
#     ambiente.neg |<28> 6  2  .  .  .  1  .  . |
#     ambiente.pos |  7<24> .  4  .  .  .  1  . |
#  atendimento.neg |  3  .<21> 8  .  .  2  .  . |
# ...

# %%
# 1. Cenário
# 2. Número de classes - 16%
# 3. ZeroRules - 21,05%

teste = 'não gostei da maneiro como fomos atendidos'
testestemming = []
stemmer = nltk.stem.RSLPStemmer()
for (palavrastreinamento) in teste.split():
    comstem = [p for p in palavrastreinamento.split()]
    testestemming.append(str(stemmer.stem(comstem[0])))
#print(testestemming)

novo = extratorpalavras(testestemming)
#print(novo)

print(classificador.classify(novo))
distribuicao = classificador.prob_classify(novo)
for classe in distribuicao.samples():
    print("%s: %f" % (classe, distribuicao.prob(classe)))
# Out:
# atendimento.neg
# atendimento.pos: 0.380951
# produto.pos: 0.002870
# ambiente.pos: 0.004868
# ambiente.neg: 0.011757
# produto.neg: 0.006440
# atendimento.neg: 0.593114

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sn

# %%
df5 = pd.read_csv("3.csv")

# %%
df1 = pd.read_csv("commentsnovo.csv")

# %%
df1
# Out:
#     comment_ID  comment_post_ID          comment_author  \
# 0           10              176                Tatetuba
# 1           11              176         Vila Industrial
# 2           12              176         Vila Industrial
# 3           13              176         Vila Industrial
# 4           14              279            vila tesouro
# 5           15              279            vila tesouro
# 6           16              279              vila maria
# 7           18              279              vila maria
# 8           19              279          vila terezinha
# 9           20              279  juan.p_sjc@hotmail.com
# 10          21              279          vila terezinha
# 11          22              279          jardim morumbi
# 12          23              279          jardim jussara
# 13          24              279              vila maria
# 14          25              279              vila maria
# 15          26              176          vila terezinha
# ...

# %%
df6 = df1[df1['comment_post_ID'] == 279] 
df6
# Out:
#     comment_ID  comment_post_ID          comment_author  \
# 4           14              279            vila tesouro
# 5           15              279            vila tesouro
# 6           16              279              vila maria
# 7           18              279              vila maria
# 8           19              279          vila terezinha
# 9           20              279  juan.p_sjc@hotmail.com
# 10          21              279          vila terezinha
# 11          22              279          jardim morumbi
# 12          23              279          jardim jussara
# 13          24              279              vila maria
# 14          25              279              vila maria
#
#       comment_author_email  comment_author_url comment_author_IP  \
# 4         flavio@ig.com.br                 NaN   179.100.113.166
# 5           luis@gmail.com                 NaN   179.100.113.166
# 6          vitor@gmail.com                 NaN   179.100.113.166
# ...

# %%
df6.rename(columns={'comment_author': 'Bairro','comment_author_email': 'Email','comment_content': 'Comentario', 'meta:custom_field_5e20f0dbd7cf4': 'Cidade'}, inplace=True)

# %%
df6.drop(columns=['comment_author_IP','comment_author_url','comment_ID','comment_post_ID','comment_date','comment_type','comment_alter_id','user_id','comment_parent','comment_approved','comment_date_gmt'])
# Out:
#                     Bairro                   Email  \
# 4             vila tesouro        flavio@ig.com.br
# 5             vila tesouro          luis@gmail.com
# 6               vila maria         vitor@gmail.com
# 7               vila maria    fabricio12@gmail.com
# 8           vila terezinha          luis@gmail.com
# 9   juan.p_sjc@hotmail.com  juan.p_sjc@hotmail.com
# 10          vila terezinha       luisz22@gmail.com
# 11          jardim morumbi     luisz1322@gmail.com
# 12          jardim jussara      carlos12@gmail.com
# 13              vila maria        igor15@gmail.com
# 14              vila maria        jose15@gmail.com
#
#                                            Comentario               Cidade  \
# 4                          O barbeiro sabe o que faz!  Sao jose dos campos
# 5    A barbearia tem ar condicionado, vende cervej...  Sao jose dos campos
# 6              ficou show o meu corte! muito obrigado  Sao jose dos campos
# ...

# %%
vet = df6['Comentario']
print(vet)
# Out:
# 4                            O barbeiro sabe o que faz!
# 5      A barbearia tem ar condicionado, vende cervej...
# 6                ficou show o meu corte! muito obrigado
# 7                        Mandam bem de mais os babeiros
# 8                           o pezinho é muito bem feito
# 9                              muito bom o atendimento!
# 10                             Muito bom o atendimento!
# 11                   Demora muito para cortar o cabelo!
# 12      Gostei muito do corte de cabelo!! virei freguês
# 13     Demora um pouco para cortar mas o barbeiro é ...
# 14     O barbeiro é gente boa de mais! e tem ótimas ...
# Name: Comentario, dtype: object

# %%
df = pd.DataFrame(data=vet)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                            Comentario
# 0                          O barbeiro sabe o que faz!
# 1    A barbearia tem ar condicionado, vende cervej...
# 2              ficou show o meu corte! muito obrigado
# 3                      Mandam bem de mais os babeiros
# 4                         o pezinho é muito bem feito
# 5                            muito bom o atendimento!
# 6                            Muito bom o atendimento!
# 7                  Demora muito para cortar o cabelo!
# 8     Gostei muito do corte de cabelo!! virei freguês
# 9    Demora um pouco para cortar mas o barbeiro é ...
# 10   O barbeiro é gente boa de mais! e tem ótimas ...

# %%
qtde = len(vet)
n=0
print(qtde)
lista_avaliação=[]
lista_atend_pos=[]
lista_amb_pos = []
lista_prod_pos = []
lista_atend_neg=[]
lista_prod_neg = []
lista_amb_neg= []
# Out:
# 11

# %%
vet = df['Comentario']
print(vet)
# Out:
# 0                            O barbeiro sabe o que faz!
# 1      A barbearia tem ar condicionado, vende cervej...
# 2                ficou show o meu corte! muito obrigado
# 3                        Mandam bem de mais os babeiros
# 4                           o pezinho é muito bem feito
# 5                              muito bom o atendimento!
# 6                              Muito bom o atendimento!
# 7                    Demora muito para cortar o cabelo!
# 8       Gostei muito do corte de cabelo!! virei freguês
# 9      Demora um pouco para cortar mas o barbeiro é ...
# 10     O barbeiro é gente boa de mais! e tem ótimas ...
# Name: Comentario, dtype: object

# %%
#armazenando nas listas os comentários 

while n <= qtde:    
    testestemming = []
    stemmer = nltk.stem.RSLPStemmer()

    
    for (palavrastreinamento) in str(vet[n]).split():
        comstem = [p for p in palavrastreinamento.split()]
        testestemming.append(str(stemmer.stem(comstem[0])))
        
        
        
        
    novo = extratorpalavras(testestemming)

    lista_avaliação.append(classificador.classify(novo))
    if classificador.classify(novo) == 'atendimento.pos':
        lista_atend_pos.append(vet[n])
    elif classificador.classify(novo) == 'ambiente.pos':
        lista_amb_pos.append(vet[n]) 
    elif classificador.classify(novo) == 'produto.pos':
        lista_prod_pos.append(vet[n])
    elif classificador.classify(novo) == 'atendimento.neg':
        lista_atend_neg.append(vet[n])
    elif classificador.classify(novo) == 'produto.neg':
        lista_prod_neg.append(vet[n])
    elif classificador.classify(novo) == 'ambiente.neg':
        lista_amb_neg.append(vet[n])    
    print(classificador.classify(novo))
    
    n = n+1
    print(n)
    if n == qtde:
        n = 0
        break
print(lista_avaliação)
# Out:
# atendimento.pos
# 1
# ambiente.pos
# 2
# produto.pos
# 3
# atendimento.pos
# 4
# produto.pos
# 5
# atendimento.pos
# 6
# atendimento.pos
# 7
# produto.neg
# 8
# produto.pos
# 9
# produto.neg
# 10
# atendimento.pos
# 11
# ['atendimento.pos', 'ambiente.pos', 'produto.pos', 'atendimento.pos', 'produto.pos', 'atendimento.pos', 'atendimento.pos', 'produto.neg', 'produto.pos', 'produto.neg', 'atendimento.pos']

# %%
total = len(lista_avaliação)
positivo_atendimento = lista_avaliação.count('atendimento.pos')
positivo_ambiente = lista_avaliação.count('ambiente.pos')
positivo_produtos = lista_avaliação.count('produto.pos')
negativo_produtos = lista_avaliação.count('produto.neg')
negativo_ambiente = lista_avaliação.count('ambiente.neg')
negativo_atendimento = lista_avaliação.count('atendimento.neg')

# %%
import matplotlib.pyplot as plt
fig, ax= plt.subplots(figsize=(6,6),subplot_kw=dict(aspect="equal") )
recepe = ["positivos","negativos"]
positivo = (positivo_atendimento + positivo_ambiente + positivo_produtos)
negativo = (negativo_produtos + negativo_ambiente + negativo_atendimento)
data = [positivo, negativo]

def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} comentários)".format(pct,absolute)

wedges, texts, autotexts = ax.pie(data, autopct=lambda pct:func(pct, data), textprops=dict(color="w"))

ax.legend(wedges, recepe, title="Comentários", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=10, weight="bold")

ax.set_title("Opinião dos clientes mês de março")

plt.show()

# %%
from pylab import plot, show, legend, title, xlabel, ylabel
fig, ax= plt.subplots(figsize=(10,8), )
Produtos = [38,39,32,29,26,22,19,15,20,22,25,27]
Ambiente = [23,23,22,21,19,16,12,10,16,21,22,22]
Atendimento = [10,14,22,25,18,19,12,23,25,30,34,38]
meses = ['Jan','Fev','Mar','Abr','Mai','Jun','Jul','Ago','Set','Out','Nov','Dez']
x = meses


plt.plot( x, Produtos, color='#00FF00') # linha pontilha orange


plt.plot( x, Ambiente, color='orange')  # linha tracejada azul
plt.plot( x, Atendimento, color='#0040FF')  # linha tracejada azul

figsize=(20,20)
plt.axis([0, 12, 0, 40])
plt.title("Evolução anual das opiniões")

plt.grid(True)
plt.xlabel("meses")
plt.ylabel("comentários")
legend(['Produtos','Ambiente','Atendimento'])
plt.show()

# %%
#stopwords para ir adicionando as palavras

stopwords2 = nltk.corpus.stopwords.words('portuguese')
stopwords2.append('vou')
stopwords2.append('tão')
stopwords2.append('O')
stopwords2.append('A')
#print(stopwordsnltk)

# %%
#pspn = palavras sem pontuação positiva
pspp_produto = []
pspp_produto = []

pspp_ambiente = []
pspp_ambiente = []

pspp_atendimento = []
pspp_atendimento = []

#pspn = palavras sem pontuação negativa

pspn_produto = []
pspn_produto = []

pspn_ambiente = []
pspn_ambiente = []

pspn_atendimento = []
pspn_atendimento = []

# %%
#palavras positivas de cada modalidade

palavras_prod_positivo = nltk.word_tokenize(str(lista_prod_pos))
palavras_amb_positivo = nltk.word_tokenize(str(lista_amb_pos))
palavras_atend_positivo = nltk.word_tokenize(str(lista_atend_pos))

#palavras negativas de cada modalidade

palavras_prod_negativo = nltk.word_tokenize(str(lista_prod_neg))
palavras_amb_negativo = nltk.word_tokenize(str(lista_amb_neg))
palavras_atend_negativo = nltk.word_tokenize(str(lista_atend_neg))

# %%
import string
punctuation = string.punctuation

#pspp = palavras sem pontuação positiva

pspp_produto = [w for w in palavras_prod_positivo if w not in stopwords2]
pspp_produto = [w for w in pspp_produto if w not in punctuation]

pspp_ambiente = [w for w in palavras_amb_positivo if w not in stopwords2]
pspp_ambiente = [w for w in pspp_ambiente if w not in punctuation]

pspp_atendimento = [w for w in palavras_atend_positivo if w not in stopwords2]
pspp_atendimento = [w for w in pspp_atendimento if w not in punctuation]

#pspn = palavras sem pontuação negativa

pspn_produto = [w for w in palavras_prod_negativo if w not in stopwords2]
pspn_produto = [w for w in pspn_produto if w not in punctuation]

pspn_ambiente = [w for w in palavras_amb_negativo if w not in stopwords2]
pspn_ambiente = [w for w in pspn_ambiente if w not in punctuation]

pspn_atendimento = [w for w in palavras_atend_negativo if w not in stopwords2]
pspn_atendimento = [w for w in pspn_atendimento if w not in punctuation]

print(pspp_produto)
print(pspp_ambiente)
print(pspp_atendimento)

print(pspn_produto)
print(pspn_ambiente)
print(pspn_atendimento)
# Out:
# ['ficou', 'show', 'corte', 'obrigado', 'pezinho', 'bem', 'feito', 'Gostei', 'corte', 'cabelo', 'virei', 'freguês']
# ['barbearia', 'ar', 'condicionado', 'vende', 'cerveja', 'visual', 'top']
# ['barbeiro', 'sabe', 'faz', 'Mandam', 'bem', 'babeiros', 'bom', 'atendimento', 'Muito', 'bom', 'atendimento', 'barbeiro', 'gente', 'boa', 'ótimas', 'histórias']
# ['Demora', 'cortar', 'cabelo', 'Demora', 'pouco', 'cortar', 'barbeiro', 'bom']
# []
# []

# %%
#Palavras positivas com relação ao Produto
from collections import Counter  #montando uma tuple com o assunto e quantidade de vezes que foi falado
pp = Counter(pspp_produto)
pp.most_common()  
top_produtos = pp.most_common(20)  
top_produtos
# Out:
# [('corte', 2),
#  ('ficou', 1),
#  ('show', 1),
#  ('obrigado', 1),
#  ('pezinho', 1),
#  ('bem', 1),
#  ('feito', 1),
#  ('Gostei', 1),
#  ('cabelo', 1),
#  ('virei', 1),
#  ('freguês', 1)]

# %%
#Palavras positivas com relação ao Ambiente

ap = Counter(pspp_ambiente)
ap.most_common()  
top_ambiente = ap.most_common(20)  
top_ambiente
# Out:
# [('barbearia', 1),
#  ('ar', 1),
#  ('condicionado', 1),
#  ('vende', 1),
#  ('cerveja', 1),
#  ('visual', 1),
#  ('top', 1)]

# %%
#Palavras positivas com relação ao Atendimento

atp = Counter(pspp_atendimento)
atp.most_common()  
top_atendimento = atp.most_common(20)  
top_atendimento
# Out:
# [('barbeiro', 2),
#  ('bom', 2),
#  ('atendimento', 2),
#  ('sabe', 1),
#  ('faz', 1),
#  ('Mandam', 1),
#  ('bem', 1),
#  ('babeiros', 1),
#  ('Muito', 1),
#  ('gente', 1),
#  ('boa', 1),
#  ('ótimas', 1),
#  ('histórias', 1)]

# %%
#Palavras negativas com relação ao produto

pn = Counter(pspn_produto)
pn.most_common()  
criticas_produto = pn.most_common(20)  
criticas_produto
# Out:
# [('Demora', 2),
#  ('cortar', 2),
#  ('cabelo', 1),
#  ('pouco', 1),
#  ('barbeiro', 1),
#  ('bom', 1)]

# %%
#Palavras negativas com relação ao ambiente

an = Counter(pspn_ambiente)
an.most_common()  
criticas_ambiente = an.most_common(20)  
criticas_ambiente
# Out:
# []

# %%
#Palavras negativas com relação ao atendimento

atn = Counter(pspn_atendimento)
atn.most_common()  
criticas_atendimento = atn.most_common(20)  
criticas_atendimento
# Out:
# []
